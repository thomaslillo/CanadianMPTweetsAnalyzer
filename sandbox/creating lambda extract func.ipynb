# %%
import requests
import os
import json
import pandas as pd
import time
from datetime import date

# %%
# where the bearer token is stored
import config as cfg

# %% [markdown]
# ## functions

# %%
# === user list request

def bearer_oauth(r):
    """
    Method required by bearer token authentication.
    """
    token = cfg.twitter_keys['BEARER_TOKEN']
    r.headers["Authorization"] = f"Bearer {token}"
    r.headers["User-Agent"] = "v2RecentSearchPython"
    return r

def get_list(url, params):
    response = requests.get(url, auth=bearer_oauth, params=params)
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

def users_request():
    list_req_url = "https://api.twitter.com/1.1/lists/members.json"
    parlListId = 864088912087715840
    query_params = {'list_id': '{}'.format(parlListId), 'count': '5000'}
    json_response = get_list(list_req_url, query_params)
    return json_response

def id_list():
    json_response = users_request()
    # extract the user IDs
    members = pd.DataFrame.from_dict(json_response['users'])
    user_ids = list(members['id'])
    return user_ids

def user_list():
    json_response = users_request()
    members = pd.DataFrame.from_dict(json_response['users'])
    mem_list = members[['id','name','screen_name']]
    return mem_list

# === user information requests

def create_headers():
    """
    create the request headers, includes the token
    """
    headers = {"Authorization": "Bearer {}".format(cfg.twitter_keys['BEARER_TOKEN'])}
    return headers

def connect_to_endpoint(url, headers):
    """
    connect to the API and return the json response
    """
    response = requests.request("GET", url, headers=headers)
    if response.status_code != 200:
        print(response.status_code)
        raise Exception(response.status_code, response.text)
    return response.json()

def api_request(search_url):
    headers = create_headers()
    json_response = connect_to_endpoint(search_url, headers)
    #return json.dumps(json_response, indent=4, sort_keys=True)
    return json_response


def extract(user_id_list):
    """
    Extracts all MPs past 30 tweets. Returns a list of JSON objects that represent each MPs activity.
    """
    # list to hold all of the json responses
    aggregate_data = []
    
    # request data for each user in the user list
    for user in user_id_list:
        # define which fields will be returned
        tweet_fields = 'created_at,author_id,conversation_id,entities,in_reply_to_user_id,referenced_tweets,text,public_metrics'
        user_fields = 'username,public_metrics,verified,url,id'
        max_results = '30'

        # the user request url
        search_url = "https://api.twitter.com/2/users/{}/tweets?tweet.fields={}&user.fields={}&max_results={}".format(user,tweet_fields,user_fields,max_results)
        response = api_request(search_url)

        aggregate_data.append(response)
        #time.sleep(1)
    
    # return the data in a list
    return aggregate_data


def transform_users(user_list):
    user_list = user_list.to_json() # make it json
    user_list = json.loads(user_list)
    user_list['date'] = str(date.today()) # add the date of collection

    return user_list

def transform_tweets():
    print('do it')

# %% [markdown]
# ## Run the program - the main() function steps

# %% [markdown]
# #### table 1 - user data

# %%
# get the user dataframe
user_list = user_list()
# Out:
# 200

# %%
# transform it
loadable_user_list = transform_users(user_list)

# %%
loadable_user_list
# Out:
# {'id': {'0': 1204044181037101057,
#   '1': 1198299741060239360,
#   '2': 1192858611879428097,
#   '3': 1187132490684784642,
#   '4': 1173429508034220032,
#   '5': 1172345859905871872,
#   '6': 1170770038208565248,
#   '7': 1166717268975333376,
#   '8': 1162219997977960449,
#   '9': 1148197780583849984,
#   '10': 1143342270399373313,
#   '11': 1143229947932229632,
#   '12': 1140090941195325440,
#   '13': 1125543746697924609,
#   '14': 1113280044934340610,
#   '15': 1086084557009575936,
#   '16': 1084856644687679496,
#   '17': 1072606577566183424,
#   '18': 1063494232126689280,
#   '279': 47692251,
#   '280': 47338701,
#   '281': 45923631,
#   '282': 45848808,
#   '283': 44718864,
#   '284': 43510607,
#   '285': 40550119,
#   '286': 38625077,
#   '287': 38262290,
#   '288': 38100599,
#   '289': 36133644,
#   '290': 35018890,
#   '291': 34606493,
#   '292': 32915303,
#   '293': 29754743,
#   '294': 28804785,
#   '295': 27079065,
#   '296': 25227444,
#   '297': 25127782,
#   '298': 24558868,
#   '299': 24543481,
#   '300': 24171225,
#   '301': 22849568,
#   '302': 21687438,
#   '303': 20199202,
#   '304': 19750015,
#   '305': 19634262,
#   '306': 19557595,
#   '307': 18654401,
#   '308': 17823761,
#   '309': 16279532,
#   '310': 16278177,
#   '311': 16220555,
#   '312': 16189107,
#   '313': 16180205,
#   '314': 16014404,
#   '315': 15810950,
#   '316': 14538949,
#   '317': 14260960,
#   '318': 3358671},
#  'name': {'0': 'Gerald Soroka',
#   '1': 'kyleseeback',
#   '2': 'Mike Kelloway',
#   '3': 'Louise Chabot',
#   '4': 'Claude DeBellefeuille',
#   '5': 'Mumilaaq Qaqqaq',
#   '6': 'Annie Koutrakis',
#   '7': 'Jaime Battiste',
#   '8': 'Patrick Weiler',
#   '9': 'Sameer Zuberi 🇨🇦',
#   '10': 'Maninder Sidhu',
#   '11': 'Luc Desilets, député de Rivière-des-Mille-Îles⚜️🎗',
#   '12': 'Ryan Turnbull',
#   '13': 'Marie-Hélène Gaudreau, députée⚜️🎗',
#   '14': 'Jeremy Patzer',
#   '15': 'Alex Ruff',
#   '16': 'Scot Davidson',
#   '17': 'MP Derek Sloan',
#   '18': 'Julie Vignola',
#   '19': 'Greg McLean',
#   '20': 'Chris Lewis MP Essex',
#   '21': 'Dave Epp',
#   '22': 'Philip Lawrence, MP',
#   '23': 'Brad Redekopp',
#   '24': 'Richard Martel',
#   '25': 'Doug Shipley',
#   '26': 'Lianne Rood',
#   '27': 'Patricia Lattanzio',
#   '28': 'Marilyn Gladu',
#   '29': 'Simon Marcil ⚜️',
#   '30': 'Bob Benzen 🇨🇦',
#   '31': 'MPIqra Khalid Office',
#   '32': 'Dominic LeBlanc',
#   '33': 'Glen Motz',
#   '34': 'Joël Godin',
#   '35': 'Rosemarie Falk',
#   '36': 'Ziad Aboultaif',
#   '37': 'Monique Pauzé',
#   '38': 'Peter Fonseca 🇨🇦',
#   '39': 'Alain Therrien',
#   '40': 'Rachael Harder',
#   '41': 'Filomena Tassi',
#   '42': 'Terry Dowdall',
#   '43': 'Serge Cormier',
#   '44': 'Marilène Gill ⚜️',
#   '45': 'Marwan Tabbara MP 2015-2021',
#   '46': 'Arnold Viersen, MP',
#   '47': 'Terry Sheehan',
#   '48': 'Gabriel Ste-Marie',
#   '49': 'Ginette Petitpas Taylor',
#   '50': 'MP Pat Finnigan',
#   '51': 'Kevin Waugh',
#   '52': 'Fayçal El-Khoury 🇨🇦',
#   '53': 'Kelly McCauley, MP',
#   '54': 'Ken McDonald',
#   '55': 'Michael McLeod',
#   '56': 'Maxime Blanchette-Joncas',
#   '57': 'Bill Blair',
#   '58': 'Sonia Sidhu',
#   '59': 'Stéphane Lauzon 🇨🇦',
#   '60': 'Diane Lebouthillier',
#   '61': 'Bernard Genereux',
#   '62': 'Martin Shields',
#   '63': 'Raquel Dancho',
#   '64': 'Yves Perron',
#   '65': 'Todd Doherty',
#   '66': "Jennifer O'Connell",
#   '67': 'Bob Bratina',
#   '68': 'Michel Boudrias',
#   '69': 'Shannon Stubbs',
#   '70': 'Yves Robillard',
#   '71': 'Shaun Chen',
#   '72': 'Paul Lefebvre',
#   '73': 'Ahmed Hussen',
#   '74': 'Anju Dhillon',
#   '75': 'Carla Qualtrough',
#   '76': 'Jean-Yves Duclos',
#   '77': 'Robert Morrissey',
#   '78': 'Denis Trudel',
#   '79': 'Darrell Samson',
#   '80': 'Kate Young',
#   '81': 'Tracy Gray',
#   '82': 'Bernadette Jordan',
#   '83': 'Bardish Chagger',
#   '84': 'Tim Louis',
#   '85': 'Rajsaini4kitcen',
#   '86': 'Daniel Blaikie',
#   '87': 'Jonathan Wilkinson 🇨🇦',
#   '88': 'Pat Kelly',
#   '89': 'Kristina Michaud',
#   '90': 'Jean Yip',
#   '91': 'Ed Fast',
#   '92': 'Leona Alleslev',
#   '93': 'Yasmin Ratansi MP for Don Valley East',
#   '94': 'Christine Normandin',
#   '95': 'Salma Zahid',
#   '96': "Ya'ara Saks יערה זקס",
#   '97': 'Chandra Arya',
#   '98': 'Jim Carr',
#   '99': 'Len Webber, MP',
#   '100': 'David Yurdiga',
#   '101': 'Ron Liepert',
#   '102': 'Pablo Rodriguez',
#   '103': 'Majid Jowhari',
#   '104': 'Ted Falk',
#   '105': 'Michael Chong 🇨🇦',
#   '106': 'Adam Vaughan',
#   '107': 'Laurel Collins',
#   '108': 'Michael Cooper, MP',
#   '109': 'Gary Vidal, MP',
#   '110': 'Nate Erskine-Smith',
#   '111': 'Julie Dzerowicz',
#   '112': 'Gary Anandasangaree',
#   '113': 'Ali Ehsassi',
#   '114': 'Marc Miller',
#   '115': 'Emmanuel Dubourg',
#   '116': 'Bob Saroya',
#   '117': 'Ben Lobb',
#   '118': 'Stephanie Kusie',
#   '119': 'Jenica Atwin for Fredericton',
#   '120': 'François-Philippe Champagne (FPC) 🇨🇦',
#   '121': 'Larry Maguire',
#   '122': 'Anthony Housefather',
#   '123': 'Lenore Zann',
#   '124': 'Cathay Wagantall',
#   '125': 'Peter Kent',
#   '126': 'Han Dong',
#   '127': 'Judy Sgro',
#   '128': 'David Lametti',
#   '129': 'Kerry-Lynne Findlay',
#   '130': 'Brad Vis',
#   '131': 'Ron McKinnon',
#   '132': 'Richard Bragdon MP',
#   '133': 'James Cumming',
#   '134': 'Sean Fraser',
#   '135': 'Marty Morantz',
#   '136': 'Patty Hajdu',
#   '137': 'Vance Badawey',
#   '138': 'Mel Arnold MP',
#   '139': 'Randeep S. Sarai',
#   '140': 'William Amos',
#   '141': 'Jody Wilson-Raybould 王州迪 Vancouver Granville',
#   '142': 'Marie-Claude Bibeau',
#   '143': 'Dave MacKenzie',
#   '144': 'Candice Bergen',
#   '145': 'Richard Cannings',
#   '146': 'Alexis Brunelle-Duceppe',
#   '147': 'Francis Drouin',
#   '148': 'Mona Fortier 🇨🇦',
#   '149': 'Ramesh Sangha, MP',
#   '150': 'Peter Fragiskatos',
#   '151': 'Jenny Kwan',
#   '152': 'Lloyd Longfield',
#   '153': 'Michael Kram 🇨🇦',
#   '154': 'XavierBarsalouDuval',
#   '155': 'Scott Duvall',
#   '156': 'Arif Virani',
#   '157': 'Simon-Pierre Savard-Tremblay',
#   '158': 'Churence Rogers',
#   '159': 'Maryam Monsef',
#   '160': 'Lawrence MacAulay',
#   '161': 'Sherry Romanado',
#   '162': 'Anita Anand',
#   '163': 'Hon. Deb Schulte (she/her)',
#   '164': 'Tako van Popta',
#   '165': 'Luc Thériault',
#   '166': 'Wayne Long',
#   '167': 'MFLalonde',
#   '168': 'Chris Bittle',
#   '169': 'Alain Rayes',
#   '170': 'Harjit Sajjan',
#   '171': 'Pierre Paul-Hus',
#   '172': 'Darren Fisher',
#   '173': 'Sylvie Bérubé, députée bloquiste',
#   '174': 'Julie Dabrusin',
#   '175': 'Eric Melillo',
#   '176': 'Peter Schiefke',
#   '177': 'Leah ProudLakota (she/her)',
#   '178': 'Martin Champoux',
#   '179': 'Dan Mazier',
#   '180': 'John Williamson',
#   '181': 'Marco Mendicino',
#   '182': 'Rhéal Fortin',
#   '183': 'Michael Barrett',
#   '184': "Erin O'Toole",
#   '185': 'Dr. Helena Jaczek',
#   '186': 'Warren Steinley',
#   '187': 'Rachel Bendayan',
#   '188': 'Scott Reid',
#   '189': 'Sven Spengemann',
#   '190': 'Rob Morrison',
#   '191': 'Steven Guilbeault',
#   '192': 'Lindsay Mathyssen',
#   '193': 'Mark Strahl, MP',
#   '194': 'Irek Kusmierczyk',
#   '195': 'Jack Harris',
#   '196': 'E. Lambropoulos',
#   '197': 'Andréanne Larouche',
#   '198': 'David McGuinty',
#   '199': 'Earl Dreeshen',
#   '200': 'Francesco Sorbara',
#   '201': 'Bruce Stanton',
#   '202': 'Alice Wong',
#   '203': 'Kirsty Duncan',
#   '204': 'John Barlow',
#   '205': 'Karen Vecchio',
#   '206': 'Luc Berthold',
#   '207': 'Tom Kmiec',
#   '208': 'Randall Garrison',
#   '209': 'Kenny Chiu',
#   '210': 'Mario Simard',
#   '211': 'Sean Casey',
#   '212': 'Jamie Schmale',
#   '213': 'Andrew Scheer',
#   '214': 'Alistair MacGregor',
#   '215': 'Jagmeet Singh',
#   '216': 'Alexandra Mendes',
#   '217': 'Marc Dalton',
#   '218': 'John McKay',
#   '219': 'Dean Allison',
#   '220': 'pierrepoilievre',
#   '221': 'Yvonne Jones',
#   '222': 'Rob Moore',
#   '223': 'Gagan Sikand',
#   '224': 'Garnett Genuis',
#   '225': 'Dan Vandal',
#   '226': 'Navdeep Bains',
#   '227': 'Kamal Khera',
#   '228': 'Sébastien Lemire',
#   '229': 'Charlie Angus NDP',
#   '230': 'Gord Johns',
#   '231': 'Joël Lightbound',
#   '232': 'Kevin Lamoureux',
#   '233': 'Pam Damoff',
#   '234': 'Chrystia Freeland',
#   '235': 'Francis Scarpaleggia',
#   '236': 'Alexandre Boulerice',
#   '237': 'Tim S. Uppal',
#   '238': 'Karen McCrimmon',
#   '239': 'Bob Zimmer',
#   '240': 'Taylor Bachrach',
#   '241': 'MP Scott Aitchison',
#   '242': 'Scott Simms',
#   '243': 'Terry Duguid',
#   '244': 'Anthony Rota',
#   '245': 'Steven MacKinnon',
#   '246': 'Mario Beaulieu',
#   '247': 'Marc G. Serré',
#   '248': 'Andy Fillmore',
#   '249': 'Mark Gerretsen 🇨🇦',
#   '250': 'Blaine Calkins',
#   '251': 'KerryDiotte',
#   '252': 'Catherine McKenna 🇨🇦',
#   '253': 'Soraya Martinez Ferrada',
#   '254': 'Mike Lake',
#   '255': 'Jasraj Singh Hallan',
#   '256': 'Larry Bagnell',
#   '257': 'Neil Ellis',
#   '258': 'Rachel Blaney (She/Her)',
#   '259': 'Brenda Shanahan',
#   '260': 'Adam van Koeverden',
#   '261': 'Angelo Iacono',
#   '262': 'Heather McPherson',
#   '263': 'Mark Holland',
#   '264': 'Damien C. Kurek',
#   '265': 'Marc Garneau',
#   '266': "Chris d'Entremont",
#   '267': 'Geoff Regan',
#   '268': 'Steven Blaney',
#   '269': 'Cathy McLeod',
#   '270': 'David Sweet',
#   '271': 'Paul Manly',
#   '272': 'Hon. Wayne Easter.',
#   '273': 'Rob Oliphant',
#   '274': 'Colin Carrie',
#   '275': 'Karina Gould',
#   '276': 'Carol Hughes',
#   '277': 'Bryan May',
#   '278': 'Ruby Sahota',
#   '279': 'Yvan Baker, MP',
#   '280': 'Marci Ien',
#   '281': 'Chris Warkentin',
#   '282': 'Greg Fergus',
#   '283': 'James Bezan',
#   '284': 'Anita Vandenbeld',
#   '285': 'Carolyn Bennett',
#   '286': 'Sukh Dhaliwal',
#   '287': 'Yves-F. Blanchet 🎗⚜️',
#   '288': 'John Brassard',
#   '289': 'Gérard Deltell',
#   '290': 'Randy Hoback',
#   '291': 'John Nater',
#   '292': 'James Maloney',
#   '293': 'Mary Ng',
#   '294': 'Kelly Block MP',
#   '295': 'Corey Tochor',
#   '296': 'Mélanie Joly',
#   '297': 'Dr. Hedy Fry',
#   '298': 'Dane Lloyd',
#   '299': 'Eric Duncan',
#   '300': '🇨🇦 Blake Richards 🇨🇦',
#   '301': "Seamus O'Regan Jr",
#   '302': 'Gudie Hutchings',
#   '303': 'Omar Alghabra',
#   '304': 'Brian Masse',
#   '305': 'Tony Van Bynen',
#   '306': 'Peter Julian',
#   '307': 'Niki Ashton',
#   '308': 'Matthew Green 🍊📈✊🏾',
#   '309': 'Terry Beech 黃志峰',
#   '310': 'Dan Albas',
#   '311': 'Elizabeth May',
#   '312': 'Don Davies MP',
#   '313': 'Joyce Murray 梅麗喬',
#   '314': 'Stéphane Bergeron',
#   '315': 'Matt Jeneroux',
#   '316': 'Michelle Rempel Garner',
#   '317': 'Justin Trudeau',
#   '318': 'Ken Hardie'},
#  'screen_name': {'0': 'GeraldSorokaMP',
#   '1': 'kyleseeback',
#   '2': 'mikekelloway',
#   '3': 'LouiseChabotBQ',
#   '4': 'ClaudeDBF_bq',
#   '5': 'MumilaaqQaqqaq',
#   '6': 'AnnieKoutrakis',
#   '7': 'JaimeBattiste',
#   '8': 'PatrickBWeiler',
#   '9': 'SameerZuberi',
#   '10': 'MSidhuLiberal',
#   '11': 'LucDesiletsBQ',
#   '12': 'TurnbullWhitby',
#   '13': 'MHGaudreauBQ',
#   '14': 'JeremyPatzerMP',
#   '15': 'AlexRuff17',
#   '16': 'ScotDavidsonMP',
#   '17': 'MPDerekSloan',
#   '18': 'JulieVignolaBL',
#   '19': 'GregMcLeanYYC',
#   '20': 'ChrisLewisEssex',
#   '21': 'DaveEppCKL',
#   '22': 'PLawrenceMP',
#   '23': 'BradRedekopp',
#   '24': 'richardmartelpc',
#   '25': 'DougShipleyBSOM',
#   '26': 'Lianne_Rood',
#   '27': 'PatriciaLattan3',
#   '28': 'MarilynGladuSL',
#   '29': 'SimonMarcilQc',
#   '30': 'BobBenzen',
#   '31': 'IqraKhalidMP',
#   '32': 'DLeBlancNB',
#   '33': 'GlenMotz',
#   '34': 'Joelgodinpjc',
#   '35': 'rosemarie_falk',
#   '36': 'ziad_aboultaif',
#   '37': 'm_pauze',
#   '38': 'PeterFonsecaMP',
#   '39': 'ATherrienBQ',
#   '40': 'RachaelHarderMP',
#   '41': 'FilomenaTassi',
#   '42': 'TerryDowdall',
#   '43': 'sergecormierlib',
#   '44': 'GillMarilene',
#   '45': 'marwantabbaramp',
#   '46': 'ArnoldViersen',
#   '47': 'TerrySheehanMP',
#   '48': 'Gabriel_SMarie',
#   '49': 'GinettePT',
#   '50': 'PatFinniganMP',
#   '51': 'KevinWaugh_CPC',
#   '52': 'F_ElKhoury',
#   '53': 'KellyMcCauleyMP',
#   '54': 'McDonald4Avalon',
#   '55': 'MMcLeodNWT',
#   '56': 'BlanchetteMax',
#   '57': 'BillBlair',
#   '58': 'SoniaLiberal',
#   '59': 'stephanelauzon5',
#   '60': 'DiLebouthillier',
#   '61': 'GenereuxBernard',
#   '62': 'MartinBowRiver',
#   '63': 'RaquelDancho',
#   '64': 'yvesperronbq',
#   '65': 'ToddDohertyMP',
#   '66': 'JenOConnell_',
#   '67': 'BobBratina',
#   '68': 'michelboudrias',
#   '69': 'ShannonStubbsMP',
#   '70': 'YRobillardPLC',
#   '71': 'Shaun_Chen',
#   '72': 'LefebvrePaul',
#   '73': 'HonAhmedHussen',
#   '74': 'adhillonDLL',
#   '75': 'CQualtro',
#   '76': 'jyduclos',
#   '77': 'MorrisseyEgmont',
#   '78': 'trudel_denis',
#   '79': 'darrellsamson',
#   '80': 'KateYoungMP',
#   '81': 'TracyGrayKLC',
#   '82': 'BernJordanMP',
#   '83': 'BardishKW',
#   '84': 'TimLouisKitCon',
#   '85': 'RajSainiKitCen',
#   '86': 'Daniel_Blaikie',
#   '87': 'JonathanWNV',
#   '88': 'PatKelly_MP',
#   '89': 'krimichaudbq',
#   '90': 'JeanYip3',
#   '91': 'HonEdFast',
#   '92': 'LeonaAlleslev',
#   '93': 'Yasmin_Ratansi',
#   '94': 'ChristineNorm',
#   '95': 'SalmaZahid15',
#   '96': 'YaaraSaks',
#   '97': 'AryaCanada',
#   '98': 'jimcarr_wpg',
#   '99': 'Webber4Confed',
#   '100': 'DavidYurdiga',
#   '101': 'RonLiepert',
#   '102': 'pablorodriguez',
#   '103': 'MajidJowhari',
#   '104': 'MPTedFalk',
#   '105': 'MichaelChongMP',
#   '106': 'TOAdamVaughan',
#   '107': 'Laurel_BC',
#   '108': 'Cooper4SAE',
#   '109': 'GaryAVidal',
#   '110': 'beynate',
#   '111': 'JulieDzerowicz',
#   '112': 'gary_srp',
#   '113': 'AliEhsassi',
#   '114': 'MarcMillerVM',
#   '115': 'EmmanuelDubourg',
#   '116': 'BobSaroya',
#   '117': 'BenLobbMP',
#   '118': 'StephanieKusie',
#   '119': 'JenicaAtwin',
#   '120': 'FP_Champagne',
#   '121': 'LarryMaguireMP',
#   '122': 'AHousefather',
#   '123': 'ZannLenore',
#   '124': 'cathayw',
#   '125': 'ProsaicPKent',
#   '126': 'handongontario',
#   '127': 'JudySgroMP',
#   '128': 'DavidLametti',
#   '129': 'KerryLynneFindl',
#   '130': 'BradleyVis',
#   '131': 'RonMcKinnonLib',
#   '132': 'RichardBragdon',
#   '133': 'jameskcumming',
#   '134': 'SeanFraserMP',
#   '135': 'marty_morantz',
#   '136': 'PattyHajdu',
#   '137': 'VBadawey',
#   '138': 'MelArnoldMP',
#   '139': 'randeepssarai',
#   '140': 'WillAAmos',
#   '141': 'Puglaas',
#   '142': 'mclaudebibeau',
#   '143': 'DaveMacKenzieMP',
#   '144': 'CandiceBergenMP',
#   '145': 'CanningsNDP',
#   '146': 'Alduceppe',
#   '147': 'Francis_Drouin',
#   '148': 'MonaFortier',
#   '149': 'sangharamesh',
#   '150': 'pfragiskatos',
#   '151': 'JennyKwanBC',
#   '152': 'LloydLongfield',
#   '153': 'MichaelKramSK',
#   '154': 'XBarsalouDuval',
#   '155': 'sduvall07',
#   '156': 'viraniarif',
#   '157': 'SPSTremblay',
#   '158': 'ChurenceRogers',
#   '159': 'MaryamMonsef',
#   '160': 'L_MacAulay',
#   '161': 'SherryRomanado',
#   '162': 'AnitaOakville',
#   '163': '_DebSchulte',
#   '164': 'takovanpopta',
#   '165': 'luctheriaultbq',
#   '166': 'WayneLongSJ',
#   '167': 'mflalonde',
#   '168': 'Chris_Bittle',
#   '169': 'AlainRayes',
#   '170': 'HarjitSajjan',
#   '171': 'PierrePaulHus',
#   '172': 'DarrenFisherNS',
#   '173': 'BerubeABJNE',
#   '174': 'juliedabrusin',
#   '175': 'Eric_Melillo',
#   '176': 'PeterSchiefke',
#   '177': 'LeahGazan',
#   '178': 'martchampoux',
#   '179': 'MBDan7',
#   '180': 'JohnWilliamson_',
#   '181': 'marcomendicino',
#   '182': 'RhealFortin',
#   '183': 'MikeBarrettON',
#   '184': 'erinotoole',
#   '185': 'HelenaJaczek',
#   '186': 'WarrenSteinley',
#   '187': 'RachelBendayan',
#   '188': 'ScottReidCPC',
#   '189': 'SvenTrueNorth',
#   '190': 'robmorrisonmp',
#   '191': 's_guilbeault',
#   '192': 'LMathys',
#   '193': 'markstrahl',
#   '194': 'Irek_K',
#   '195': 'JackHarrisNDP',
#   '196': 'emlambropoulos',
#   '197': 'A_Larouche_Shef',
#   '198': 'DavidMcGuinty',
#   '199': 'earl_dreeshen',
#   '200': 'fsorbara',
#   '201': 'bruce_stanton',
#   '202': 'AliceWongCanada',
#   '203': 'KirstyDuncanEN',
#   '204': 'JohnBarlowMP',
#   '205': 'karen_vecchio',
#   '206': 'LucBerthold',
#   '207': 'tomkmiec',
#   '208': 'r_garrison',
#   '209': 'RmdKenny',
#   '210': 'mariosimardbq',
#   '211': 'SeanCaseyLPC',
#   '212': 'Jamie_Schmale',
#   '213': 'AndrewScheer',
#   '214': 'AMacGregor4CML',
#   '215': 'theJagmeetSingh',
#   '216': 'AlexandraBrStL',
#   '217': 'MarcDalton',
#   '218': 'JohnMcKayLib',
#   '219': 'DeanAllisonMP',
#   '220': 'PierrePoilievre',
#   '221': 'YvonneJJones',
#   '222': 'RobMoore_CPC',
#   '223': 'gagansikand',
#   '224': 'GarnettGenuis',
#   '225': 'stbstvdan',
#   '226': 'NavdeepSBains',
#   '227': 'KamalKheraLib',
#   '228': 'seblemire',
#   '229': 'CharlieAngusNDP',
#   '230': 'GordJohns',
#   '231': 'JoelLightbound',
#   '232': 'Kevin_Lamoureux',
#   '233': 'PamDamoff',
#   '234': 'cafreeland',
#   '235': 'ScarpaleggiaLSL',
#   '236': 'alexboulerice',
#   '237': 'TimUppal',
#   '238': 'karenmccrimmon',
#   '239': 'bobzimmermp',
#   '240': 'taylorbachrach',
#   '241': 'ScottAAitchison',
#   '242': 'Scott_Simms',
#   '243': 'TerryDuguid',
#   '244': 'AnthonyRota',
#   '245': 'stevenmackinnon',
#   '246': 'Mario_Beaulieu',
#   '247': 'MarcSerreMP',
#   '248': 'AndyFillmoreHFX',
#   '249': 'MarkGerretsen',
#   '250': 'BlaineFCalkins',
#   '251': 'KerryDiotte',
#   '252': 'cathmckenna',
#   '253': 'SorayaMartinezF',
#   '254': 'MikeLakeMP',
#   '255': 'jasrajshallan',
#   '256': 'LarryBagnell',
#   '257': 'NeilREllis',
#   '258': 'RABlaney',
#   '259': 'BShanahanLib',
#   '260': 'vankayak',
#   '261': 'IaconoMP',
#   '262': 'HMcPhersonMP',
#   '263': 'markhollandlib',
#   '264': 'dckurek',
#   '265': 'MarcGarneau',
#   '266': 'CdEntremontMP',
#   '267': 'geoffregan',
#   '268': 'HonStevenBlaney',
#   '269': 'Cathy_McLeod',
#   '270': 'DavidSweetMP',
#   '271': 'paulmanly',
#   '272': 'WayneEaster',
#   '273': 'Rob_Oliphant',
#   '274': 'ColinCarrieCPC',
#   '275': 'karinagould',
#   '276': 'CarolHughesMP',
#   '277': '_BryanMay',
#   '278': 'rubysahotalib',
#   '279': 'Yvan_Baker',
#   '280': 'MarciIen',
#   '281': 'chriswarkentin',
#   '282': 'GregFergus',
#   '283': 'jamesbezan',
#   '284': 'anitavandenbeld',
#   '285': 'Carolyn_Bennett',
#   '286': 'sukhdhaliwal',
#   '287': 'yfblanchet',
#   '288': 'JohnBrassardCPC',
#   '289': 'gerarddeltell',
#   '290': 'RandyHoback',
#   '291': 'JohnNaterMP',
#   '292': 'j_maloney',
#   '293': 'mary_ng',
#   '294': 'KellyBlockmp',
#   '295': 'ctochor',
#   '296': 'melaniejoly',
#   '297': 'HedyFry',
#   '298': 'DaneLIoydMP',
#   '299': 'EricDuncanSDSG',
#   '300': 'BlakeRichardsMP',
#   '301': 'SeamusORegan',
#   '302': 'Gudie',
#   '303': 'OmarAlghabra',
#   '304': 'BrianMasseMP',
#   '305': 'TonyVanBynen',
#   '306': 'MPJulian',
#   '307': 'nikiashton',
#   '308': 'MatthewGreenNDP',
#   '309': 'terrybeech',
#   '310': 'DanAlbas',
#   '311': 'ElizabethMay',
#   '312': 'DonDavies',
#   '313': 'JoyceMurray',
#   '314': 'sbergeron',
#   '315': 'jeneroux',
#   '316': 'MichelleRempel',
#   '317': 'JustinTrudeau',
#   '318': 'KenHardie'},
#  'date': '2021-09-29'}

# %% [markdown]
# #### table 2 - mp tweets

# %%
# get the user id list
user_id_list = id_list()
# Out:
# 200

# %%
# get the tweets
mp_data = extract(user_id_list)

# %%
# transform the mp tweets

# %% [markdown]
# ### IN PROGRESS WORK

# %%
# check that we have all the MPs
print(len(mp_data))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-d0edfc890e6a> in <module>
#       1 # check that we have all the MPs
# ----> 2 print(len(mp_data))
#
# NameError: name 'mp_data' is not defined

# %%
print(aggregate_data[0]) # one tweet
# Out:
# {'data': [{'id': '1319085046934929410', 'created_at': '2020-10-22T01:15:57.000Z', 'public_metrics': {'retweet_count': 23, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'conversation_id': '1319085046934929410', 'referenced_tweets': [{'type': 'retweeted', 'id': '1318947998857109504'}], 'author_id': '1223994797834297350', 'text': 'RT @BlocQuebecois: Depuis un an, 32 députés du #BlocQc portent fièrement la voix du Québec à Ottawa. Grâce à vous, nous avons le privilège…'}, {'id': '1318664109160878087', 'created_at': '2020-10-20T21:23:17.000Z', 'public_metrics': {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'conversation_id': '1318664109160878087', 'author_id': '1223994797834297350', 'text': 'Attention! Attention! La date butoir est repoussée au vendredi 23 octobre, 15 h pour le programme Nouveaux Horizons aux aînés 2020 #polcan https://t.co/mLEGV4eB6F'}, {'id': '1317208407133257728', 'created_at': '2020-10-16T20:58:51.000Z', 'public_metrics': {'retweet_count': 28, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'conversation_id': '1317208407133257728', 'referenced_tweets': [{'type': 'retweeted', 'id': '1317133200020353025'}], 'author_id': '1223994797834297350', 'text': 'RT @BlocQuebecois: https://t.co/Vtdvla37Sv'}, {'id': '1316362620065193984', 'created_at': '2020-10-14T12:58:00.000Z', 'public_metrics': {'retweet_count': 21, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'conversation_id': '1316362620065193984', 'referenced_tweets': [{'type': 'retweeted', 'id': '1316182924174163969'}], 'author_id': '1223994797834297350', 'text': 'RT @yfblanchet: De toute beauté et si belle de sens. 🙏🏻', 'context_annotations': [{'domain': {'id': '65', 'name': 'Interests and Hobbies Vertical', 'description': 'Top level interests and hobbies groupings, like Food or Travel'}, 'entity': {'id': '847868745150119936', 'name': 'Home & family', 'description': 'Hobbies and interests'}}, {'domain': {'id': '66', 'name': 'Interests and Hobbies Category', 'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'}, 'entity': {'id': '1046577790353428480', 'name': 'Visual arts', 'description': 'Visual Arts'}}, {'domain': {'id': '67', 'name': 'Interests and Hobbies', 'description': 'Interests, opinions, and behaviors of individuals, groups, or cultures; like Speciality Cooking or Theme Parks'}, 'entity': {'id': '1046579830823706624', 'name': 'Sculpting', 'description': 'Sculpting'}}]}, {'id': '1314305747107360768', 'created_at': '2020-10-08T20:44:43.000Z', 'public_metrics': {'retweet_count': 57, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'conversation_id': '1314305747107360768', 'referenced_tweets': [{'type': 'retweeted', 'id': '1313962383069655040'}], 'author_id': '1223994797834297350', 'text': 'RT @BlocQuebecois: Crise d’octobre : le #BlocQc demande à Justin Trudeau, des excuses pour les 497 personnes incarcérées sans motif, ainsi…', 'context_annotations': [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '834164697880416257', 'name': 'Justin Trudeau', 'description': 'Canadian Prime Minister Justin Trudeau'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '834164697880416257', 'name': 'Justin Trudeau', 'description': 'Canadian Prime Minister Justin Trudeau'}}]}, {'id': '1296965138726170624', 'created_at': '2020-08-22T00:19:20.000Z', 'public_metrics': {'retweet_count': 8, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'conversation_id': '1296965138726170624', 'referenced_tweets': [{'type': 'retweeted', 'id': '1296899877004169216'}], 'author_id': '1223994797834297350', 'text': 'RT @BlocQuebecois: Accompagné des députés du #BlocQc, le chef @yfblanchet a conclu hier le caucus estival du parti en Gaspésie, dont le thè…'}, {'id': '1296964264205398025', 'created_at': '2020-08-22T00:15:51.000Z', 'public_metrics': {'ret ...

# %% [markdown]
# ### upload the list of users to the database as json

# %%
# Out:
# 200
#                       id                    name      screen_name
# 0    1223994797834297350      Charbonneau Louise  CharbonneauLou5
# 1    1204044181037101057           Gerald Soroka   GeraldSorokaMP
# 2    1198299741060239360             kyleseeback      kyleseeback
# 3    1192858611879428097       Mike Kelloway, MP     mikekelloway
# 4    1187132490684784642           Louise Chabot   LouiseChabotBQ
# ..                   ...                     ...              ...
# 316             16014404       Stéphane Bergeron        sbergeron
# 317             15810950       Matt Jeneroux, MP         jeneroux
# 318             14538949  Michelle Rempel Garner   MichelleRempel
# 319             14260960          Justin Trudeau    JustinTrudeau
# 320              3358671              Ken Hardie        KenHardie
#
# [321 rows x 3 columns]
# %% [markdown]
# #### Single Tweet Request for Testing

# %%
tweet_fields = 'created_at,author_id,conversation_id,entities,in_reply_to_user_id,referenced_tweets,text,public_metrics'
# 'id,created_at,author_id,created_at,conversation_id,lang,entities,in_reply_to_user_id,referenced_tweets,text,public_metrics'  
user_fields = 'username,public_metrics,verified,url,id'
expansions = 'author_id'
max_results = '30'

# Michelle Rempel Garner
single_user = 256069692

# the user request url
single_url = "https://api.twitter.com/2/users/{}/tweets?expansions={}&tweet.fields={}&user.fields={}&max_results={}".format(single_user,expansions,tweet_fields,user_fields,max_results)

print(single_url)

single_response = main(single_url)
# Out:
# https://api.twitter.com/2/users/256069692/tweets?expansions=author_id&tweet.fields=created_at,author_id,conversation_id,entities,in_reply_to_user_id,referenced_tweets,text,public_metrics&user.fields=username,public_metrics,verified,url,id&max_results=30
# 200

# %%
print(single_response)
print(type(single_response))
# Out:
# {'data': [{'id': '1421983432830115843', 'created_at': '2021-08-01T23:57:24.000Z', 'entities': {'mentions': [{'start': 0, 'end': 9, 'username': 'K_elly_B', 'id': '378826663'}], 'annotations': [{'start': 44, 'end': 50, 'probability': 0.9746, 'type': 'Person', 'normalized_text': 'Trudeau'}]}, 'conversation_id': '1421982750702145541', 'in_reply_to_user_id': '378826663', 'text': '@K_elly_B I think to highlight that this is Trudeau’s call and his alone.\n\nOnce campaign starts, messaging will shift gears.', 'referenced_tweets': [{'type': 'replied_to', 'id': '1421982750702145541'}], 'public_metrics': {'retweet_count': 0, 'reply_count': 1, 'like_count': 1, 'quote_count': 0}, 'author_id': '256069692'}, {'id': '1421949439615193093', 'created_at': '2021-08-01T21:42:19.000Z', 'conversation_id': '1421949439615193093', 'text': 'It’s not a fall election if E-Day is before September 21st. \n\nPlease adjust your headlines accordingly.\n\nThanks.', 'public_metrics': {'retweet_count': 2, 'reply_count': 2, 'like_count': 30, 'quote_count': 0}, 'author_id': '256069692', 'entities': {'annotations': [{'start': 28, 'end': 32, 'probability': 0.5369, 'type': 'Person', 'normalized_text': 'E-Day'}]}}, {'id': '1421935418358915072', 'created_at': '2021-08-01T20:46:36.000Z', 'entities': {'hashtags': [{'start': 30, 'end': 46, 'tag': 'EmancipationDay'}, {'start': 111, 'end': 127, 'tag': 'EmancipationDay'}], 'mentions': [{'start': 3, 'end': 19, 'username': 'theJagmeetSingh', 'id': '253340075'}], 'annotations': [{'start': 62, 'end': 67, 'probability': 0.9866, 'type': 'Place', 'normalized_text': 'Canada'}]}, 'conversation_id': '1421935418358915072', 'text': "RT @theJagmeetSingh: Today on #EmancipationDay, we reflect on Canada's very real connection to slavery.\n\nWhile #EmancipationDay marks the h…", 'referenced_tweets': [{'type': 'retweeted', 'id': '1421852613545496576'}], 'public_metrics': {'retweet_count': 193, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'author_id': '256069692'}, {'id': '1421934824101580802', 'created_at': '2021-08-01T20:44:14.000Z', 'entities': {'mentions': [{'start': 3, 'end': 10, 'username': 'acoyne', 'id': '3079986094'}], 'annotations': [{'start': 12, 'end': 23, 'probability': 0.9005, 'type': 'Person', 'normalized_text': 'Erin O’Toole'}, {'start': 84, 'end': 96, 'probability': 0.6698, 'type': 'Organization', 'normalized_text': 'Conservatives'}]}, 'conversation_id': '1421934824101580802', 'text': 'RT @acoyne: Erin O’Toole approaches an election with a party so fractured that some Conservatives want him to lose - The Star https://t.co/…', 'referenced_tweets': [{'type': 'retweeted', 'id': '1421921237329190916'}], 'public_metrics': {'retweet_count': 24, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'author_id': '256069692'}, {'id': '1421933128537436161', 'created_at': '2021-08-01T20:37:30.000Z', 'entities': {'hashtags': [{'start': 11, 'end': 18, 'tag': 'elxn44'}, {'start': 158, 'end': 162, 'tag': 'NDP'}], 'urls': [{'start': 281, 'end': 304, 'url': 'https://t.co/P4rnuQPoS6', 'expanded_url': 'https://twitter.com/AMacGregor4CML/status/1421933128537436161/photo/1', 'display_url': 'pic.twitter.com/P4rnuQPoS6'}], 'annotations': [{'start': 171, 'end': 178, 'probability': 0.5709, 'type': 'Place', 'normalized_text': 'Cowichan'}, {'start': 252, 'end': 262, 'probability': 0.9028, 'type': 'Person', 'normalized_text': 'Jack Layton'}]}, 'conversation_id': '1421933128537436161', 'text': 'Looks like #elxn44 rumours ramping up, with a possible call in next two weeks.\n\nNot an election I want, but I do love campaigning and am thankful for amazing #NDP team in Cowichan-Malahat-Langford.\n\nBroke my toe last week, so time to channel some 2011 Jack Layton campaign energy! https://t.co/P4rnuQPoS6', 'public_metrics': {'retweet_count': 5, 'reply_count': 3, 'like_count': 35, 'quote_count': 0}, 'author_id': '256069692'}, {'id': '1421931772221132801', 'created_at': '2021-08-01T20:32:07.000Z', 'entities': {'hashtags': [{'start': 81, 'end': 97, 'tag':  ...
# <class 'dict'>

# %%
print(single_response['data'][0]) # each value in the list is a tweet - loop through all 30 to take the goods
# Out:
# {'id': '1421983432830115843', 'created_at': '2021-08-01T23:57:24.000Z', 'entities': {'mentions': [{'start': 0, 'end': 9, 'username': 'K_elly_B', 'id': '378826663'}], 'annotations': [{'start': 44, 'end': 50, 'probability': 0.9746, 'type': 'Person', 'normalized_text': 'Trudeau'}]}, 'conversation_id': '1421982750702145541', 'in_reply_to_user_id': '378826663', 'text': '@K_elly_B I think to highlight that this is Trudeau’s call and his alone.\n\nOnce campaign starts, messaging will shift gears.', 'referenced_tweets': [{'type': 'replied_to', 'id': '1421982750702145541'}], 'public_metrics': {'retweet_count': 0, 'reply_count': 1, 'like_count': 1, 'quote_count': 0}, 'author_id': '256069692'}

# %% [markdown]
# ## ignore this ending part

# %%
first_tweet = single_response['data'][0]

first_tweet_id = int(first_tweet['author_id'])

author = user_list.loc[user_list['id'] == first_tweet_id]

# %%
print(author)
# Out:
#             id                name     screen_name
# 216  256069692  Alistair MacGregor  AMacGregor4CML

# %%
single_response_with_auth = single_response

single_response_with_auth['author_name'] = author['name']
